# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import wandb

from nerf2d_dataset import NeRF2D_Datamodule
from wandb_utils import get_artifact_dir_api

api = wandb.Api()
dataset_folder = get_artifact_dir_api(api, 'romeu/NeRF2D/bunny:v1')
dm = NeRF2D_Datamodule(dataset_folder)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# wandb:   506 of 506 files downloaded.

# %%
from nerf2d_dataset import plot_poses

fig = plot_poses(dm.test_poses)
fig.tight_layout()
plt.show()
