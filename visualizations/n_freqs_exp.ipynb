# %%
from wandb_utils import RunWrapper
# %load_ext autoreload
# %autoreload 2
import wandb

api = wandb.Api()
project = 'romeu/NeRF2D'
runs = api.runs(f"{project}")
runs = [RunWrapper(r) for r in runs if 'n_freqs_exp' in r.tags]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pathlib import Path
from wandb_utils import RunDataManager
from visualizations.figures import make_gif_from_run

manager = RunDataManager(Path('../run_data'))

for r in runs:
    make_gif_from_run(manager, r, 'density', f'/home/jorge/nerf2d/density_{r.run.name}.gif')
# Out:
# ...
# 100%|██████████| 52/52 [00:29<00:00,  1.79it/s]

# %%
from visualizations.figures import compare_runs

compare_runs(runs, manager)
# Out:
# ...
# 100%|██████████| 1/1 [00:00<00:00, 653.11it/s]
